# %% [markdown]
# # Isoline Estimation Methods: Exploration and Analysis
#
# A notebook to explore the properties of various isoline estimation methodologies, including those of Cooley (2019), Salvadore and de Michele (2004), Wadsworth (2017), and new strategies based on regular variation.

# %%
library(ggplot2)
library(dplyr)
library(mvtnorm)

# %%
source('~/isolines_uq/scripts/R/auxiliary_scripts/orig_isolines.R')
source('~/isolines_uq/scripts/R/auxiliary_scripts/distributionIsolines.R')

# %%
q <- 0.001
iso <- drawBivtIsoline(numCoords=100, gridLbs=c(-2,-2), gridUbs=c(10,10), prob=q)

# %%
n <- 10000
dat <- data.frame(rmvt(n = n, sigma = matrix(c(1, 0.4, 0.4, 1), nrow=2), df = 4))

# %%
res <- xContours(dat=dat, baseContourLevel=0.01, projContourLevels=c(q))

# %%
plot(res$projContours[[1]])
# Out:
# plot without title

# %%
# Out:
# No documentation for ‘Frechet’ in specified packages and libraries:
# you could try ‘??Frechet’
